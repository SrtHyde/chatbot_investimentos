# %% [markdown]
# # Atualizar:
# - Melhorar função de testar similaridade
# - Adicionar memória com limite de mensagens no chat
# - Melhorar interface Gradio

# %%
import gradio as gr
import chromadb
#import asyncio
import nest_asyncio
from glob import glob
from PyPDF2 import PdfReader
from os import path, getenv
from dotenv import load_dotenv
from llama_parse import LlamaParse
from llama_index.core.schema import TextNode
from llama_index.llms.huggingface_api import HuggingFaceInferenceAPI
from llama_index.core import SimpleDirectoryReader, VectorStoreIndex, Settings
from llama_index.core.node_parser import SentenceSplitter, SemanticSplitterNodeParser
from llama_index.embeddings.huggingface import HuggingFaceEmbedding
from llama_index.vector_stores.chroma import ChromaVectorStore
#import re
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
#from typing import List, Dict

# %% [markdown]
# # Implementação Chroma + LLamaIndex

# %%
class Config:
    def __init__(self):
        load_dotenv()
        #self.llm_model = getenv('llm_model')
        self.llm_model = "mistralai/Mistral-Nemo-Instruct-2407"
        self.embedding_model = getenv('embedding_model')
        self.api_key = getenv('api_key')
        self.db_path = getenv('db_path')
        self.input_dir = getenv('input_dir')
        self.collection_name = getenv('collection_name')
        self.parser_key = getenv('parser_key')
        self.connection = None

    def connect_db(self):
        try:
            db_client = chromadb.PersistentClient(path=self.db_path)
            collection = db_client.get_or_create_collection(self.collection_name)
            self.connection = ChromaVectorStore(chroma_collection=collection)
            
            print("Conexão ao ChromaDB estabelecida com sucesso!")
            return self.connection
        except Exception as e:
            raise Exception(f"Erro ao conectar ao banco de dados: {str(e)}")

# %% [markdown]
# ## Uso do LlamaParse + SemanticSplitterNodeParser

# %%
class GenarateIndex:
    def __init__(self):
        self.config = Config()
        self.vector_store = self.config.connect_db()
        self.llm_model = self.config.llm_model
        self.embed_model_name = self.config.embedding_model
        self.input_dir = self.config.input_dir
        self.api_key = self.config.api_key
        self.parser_key = self.config.parser_key
        self.nodes = None

    def generate_index(self):
        try:
            self.embedding_model = HuggingFaceEmbedding(model_name=self.embed_model_name)
            Settings.node_parser = SemanticSplitterNodeParser(buffer_size=1,
                                                              include_metadata = True, 
                                                              breakpoint_percentile_threshold=50,
                                                              include_prev_next_rel = True,
                                                              embed_model=self.embedding_model)
            
            self.nodes = Settings.node_parser.get_nodes_from_documents(self.documents)
            self.index = VectorStoreIndex(
                nodes = self.nodes,
                vector_store=self.vector_store,
                embed_model=self.embedding_model,
                show_progress=True,
            )

            print("Índice gerado com sucesso!")
            return self.index
        except Exception as e:
            raise Exception(f"Erro ao gerar índice: {str(e)}")

    async def process_pdfs(self, input_dir):
        nest_asyncio.apply()
        """
        Processa arquivos PDF em um diretório e extrai texto.
        """
        files = glob(f"{input_dir}/*.pdf")

        try:
            parser = LlamaParse(api_key=self.parser_key, result_type="markdown",)

            for file in files:
               
               file_extractor = {".pdf": parser}
               reader = SimpleDirectoryReader(
                   input_files=[file],
                   file_extractor=file_extractor
               )
               
               # Carregar dados de forma assíncrona
               self.documents = await reader.aload_data()
               
               if not self.documents:
                 raise ValueError(f"O PDF {file} parece não conter texto processável.")
            
            return self.documents
        except Exception as e:
            raise Exception(f"Erro ao processar PDFs: {str(e)}")
        
    async def execute(self):
        try:
            nest_asyncio.apply()
            await self.process_pdfs(self.input_dir)
            self.generate_index()
            return self.index
        except Exception as e:
            raise Exception(f"Erro ao executar o processo: {str(e)}")

# %% [markdown]
# ## Uso do llamaparse + tratamento em função de chunks por qtd de palavras

# %%
        

class GenarateIndex:
    def __init__(self):
        self.config = Config()
        self.vector_store = self.config.connect_db()
        self.llm_model = self.config.llm_model
        self.embed_model_name = self.config.embedding_model
        self.input_dir = self.config.input_dir
        self.api_key = self.config.api_key
        self.parser_key = self.config.parser_key
        self.nodes = None

    def generate_index(self):
        try:
            Settings.embed_model = HuggingFaceEmbedding(model_name=self.embed_model_name)
            Settings.node_parser = SentenceSplitter(chunk_size=512, chunk_overlap=50)

            self.index = VectorStoreIndex(
                nodes = self.nodes,
                vector_store=self.vector_store,
                embed_model=self.embedding_model,
                show_progress=True,
            )

            print("Índice gerado com sucesso!")
            return self.index
        except Exception as e:
            raise Exception(f"Erro ao gerar índice: {str(e)}")

    def split_into_chunks(self, text, chunk_size=150, overlap=50):
        """
        Divide o texto em chunks de palavras com overlap especificado.

        :param text: Texto completo que será dividido.
        :param chunk_size: Número de palavras em cada chunk.
        :param overlap: Quantidade de palavras que se sobrepõem entre chunks.
        :return: Lista de chunks de texto.
        """
        words = text.split()  # Divide o texto em uma lista de palavras
        chunks = []
        start = 0
        while start < len(words):
            end = start + chunk_size
            chunk = " ".join(words[start:end])  # Junta as palavras para formar o chunk
            chunks.append(chunk)
            start += chunk_size - overlap  # Avança, considerando o overlap
        return chunks

    async def process_pdfs(self, input_dir):
        nest_asyncio.apply()
        """
        Processa arquivos PDF em um diretório, extrai texto e o divide em chunks.
        """
        files = glob(f"{input_dir}/*.pdf")
        text_nodes = []

        try:
            parser = LlamaParse(api_key=self.parser_key, result_type="markdown",)

             #Processar cada arquivo PDF
            for file in files:
                # Usar SimpleDirectoryReader com LlamaParse para extração de texto
                file_extractor = {".pdf": parser}
                reader = SimpleDirectoryReader(
                    input_files=[file],
                    file_extractor=file_extractor
                )
                
                # Carregar dados de forma assíncrona
                documents = await reader.aload_data()
                if not documents:
                    raise ValueError(f"O PDF {file} parece não conter texto processável.")
            
                # Concatenar texto dos documentos e dividir em chunks
                text = " ".join([doc.text for doc in documents])
                chunks = self.split_into_chunks(text)
            
                # Criar nós de texto para o índice
                for idx, chunk in enumerate(chunks, start=1):
                    text_nodes.append(TextNode(
                        text=chunk,
                        metadata={"filename": file, "num_chunk": idx}
                    ))
            
                print(f"Texto extraído do arquivo {file} com sucesso!")
            
            self.nodes = list(text_nodes)

            if not self.nodes:
                 raise ValueError(f"O PDF {file} parece não conter texto processável.")
            
            return self.nodes
        except Exception as e:
            raise Exception(f"Erro ao processar PDFs: {str(e)}")
        
    async def execute(self):
        try:
            nest_asyncio.apply()
            await self.process_pdfs(self.input_dir)
            self.generate_index()
            return self.index
        except Exception as e:
            raise Exception(f"Erro ao executar o processo: {str(e)}")

# %% [markdown]
# ## Pdfreader

# %%
class GenarateIndex:
    def __init__(self):
        self.config = Config()
        self.vector_store = self.config.connect_db()
        self.llm_model = self.config.llm_model
        self.embed_model_name = self.config.embedding_model
        self.input_dir = self.config.input_dir
        self.api_key = self.config.api_key
        self.nodes = None

    def generate_index(self):
        try:
            #self.embedding_model = HuggingFaceEmbedding(model_name=self.embed_model_name)
            Settings.embed_model = HuggingFaceEmbedding(model_name=self.embed_model_name, trust_remote_code=True)
            Settings.node_parser = SentenceSplitter(chunk_size=512, chunk_overlap=50)
            Settings.num_output = 512
            Settings.context_window = 3900
            self.index = VectorStoreIndex(
                nodes = self.nodes,
                vector_store=self.vector_store,
                #embed_model=self.embedding_model,
                show_progress=True,
            )
            print("Índice gerado com sucesso!")
            return self.index
        except Exception as e:
            raise Exception(f"Erro ao gerar índice: {str(e)}")

    def split_into_chunks(self, text, chunk_size=150, overlap=50):
        """
        Divide o texto em chunks de palavras com overlap especificado.

        :param text: Texto completo que será dividido.
        :param chunk_size: Número de palavras em cada chunk.
        :param overlap: Quantidade de palavras que se sobrepõem entre chunks.
        :return: Lista de chunks de texto.
        """
        words = text.split()  # Divide o texto em uma lista de palavras
        chunks = []
        start = 0
        while start < len(words):
            end = start + chunk_size
            chunk = " ".join(words[start:end])  # Junta as palavras para formar o chunk
            chunks.append(chunk)
            start += chunk_size - overlap  # Avança, considerando o overlap
        return chunks
    
    def process_pdfs(self, input_dir):
        files = glob(f"{input_dir}/*.pdf")
        text_nodes = []
        try:
            for file in files:
                reader = PdfReader(file)
                text = ""
                
                for page in reader.pages:
                    extracted_text = page.extract_text().replace('\n', ' ').replace('  ', ' ')
                    print
                    if extracted_text:
                        text += extracted_text + " "
                
                if not text.strip():
                    raise ValueError(f"O PDF {file} parece não conter texto processável.")
                
                chunks = self.split_into_chunks(text)
                
                # Armazenando os chunks de texto e metadados
                for chunk in chunks:
                    cont =+ 1
                    text_nodes.append(TextNode(
                    text=chunk,
                    metadata={"filename": file, "num_chunk": cont},
                    
                ))
                # Armazenando o texto extraído e metadados
                
                print(f"Texto extraído do arquivo {file} com sucesso!")
            self.nodes = list(text_nodes)
            return self.nodes
        except Exception as e:
            raise Exception(f"Erro ao transformar texto: {str(e)}")
        
    def execute(self):
        try:
            self.process_pdfs(self.input_dir)
            self.generate_index()
            return self.index
        except Exception as e:
            raise Exception(f"Erro ao executar o processo: {str(e)}")

# %% [markdown]
# # Chatbot

# %%
class ChatBot:
    def __init__(self, index):
        self.config = Config()
        self.api_key = self.config.api_key
        self.llm_model = self.config.llm_model
        self.index = index
        

    def initialize_llm(self):
        try:
            self.prompt = (
                    "Essas são suas diretrizes para interagir com os usuários: "
                    "Seu nome é BOOT. "
                    "Você é um assistente virtual projetado para fornecer informações sobre diversos tópicos. "
                    "Responda exclusivamente em !![]português. "
                    "Caso o usuário inicie a conversa com uma saudação, cumprimento ou pergunte quem você é ou sobre voê, APENAS apresente-se de forma cordial e simpática. "
                    "Responda com base no que sabe e adapte suas respostas de forma a se encaixar perfeitamente na pergunta ou necessidade do usuário. "
                    "!![]Não use os termos 'Resposta:' ou 'Pergunta:' ao iniciar suas mensagens. "
                    "Seja educado em todas as interações."
                    "Sempre atenda aos pedidos do usuário em !![]português."
                    )
            Settings.llm = HuggingFaceInferenceAPI(model_name=self.llm_model, 
                                                   token=self.api_key, 
                                                   system_prompt=self.prompt,
                                                   generate_kwargs={"temperature": 0.9})

            Settings.num_output = 1000
            Settings.context_window = 5000

            chat_engine = self.index.as_chat_engine(
                chat_mode="condense_question",
                verbose=False
            )

            return chat_engine
            
        except Exception as e:
            raise Exception(f"Erro ao inicializar Modelo: {str(e)}")
        
    def get_similarity(self, query, context):

        """Calcula a similaridade entre a pergunta e o contexto usando TF-IDF e cosine similarity."""
        filtered_context = []
        for node in context.split('|'):

            vectorizer = TfidfVectorizer().fit_transform([query, node])
            similarity_matrix = cosine_similarity(vectorizer[0:1], vectorizer[1:])
      
            
            if similarity_matrix[0][0] > 0.01:
                print(node)
                filtered_context.append(node)
                print(f"Similaridade: {similarity_matrix}")
                print("---------------------------")

        filtered_context = "\n".join(filtered_context)
        return filtered_context
        
    def search(self, query):

        try:

            query_engine = self.index.as_query_engine(
                llm=HuggingFaceInferenceAPI(model_name=self.llm_model, token=self.api_key),
                response_mode="tree_summarize",
                similarity_top_k=5,
                verbose=False
            )
            response = query_engine.query(query)
            context = "|".join([doc.node.text for doc in response.source_nodes])

            filtered_context = self.get_similarity(query, context)
            print(f"Contexto: {filtered_context}")

            return response, filtered_context

        except Exception as e:
            raise Exception(f"Erro ao realizar a busca: {str(e)}")
        
        
    def respond(self, message, history=None):
        """Gera uma resposta baseada no contexto da pesquisa."""
        try:
            
            # Busca o contexto no ChromaDB
            chat_engine = self.initialize_llm()
            response, context = self.search(message)

            message_context = f"Contexto: {context} || Pergunta: {message}"

            # Gera a resposta usando o motor de chat
            response = chat_engine.chat(message_context)
            print(message_context)
            return response.response
        
        except Exception as e:
            return f"Erro ao processar mensagem: {str(e)}"

    def interface(self): 
        with gr.Blocks(theme=gr.themes.Base()) as demo:
            # CSS para personalizar o tamanho da área do chatbot
            css = """
            .gr-chatbot {
                height: 600px !important; /* Ajuste a altura desejada */
                overflow-y: auto; /* Permite rolagem se necessário */
            }
            .toast-wrap { 
                display: none !important; 
            }
            """
            
            gr.ChatInterface(
                self.respond, 
                type="messages",
                title="Boot",  
                css=css, 
                examples=["hello", "hola", "merhaba", "oi"],
            ) 
        
        
        return demo.queue().launch(debug=True)

# %%
generate_index = GenarateIndex()
index = await generate_index.execute()
# Out:
# Conexão ao ChromaDB estabelecida com sucesso!
# Started parsing the file under job_id 3011dd08-82f8-49e0-9628-b0650da0240f
# Generating embeddings:   0%|          | 0/154 [00:00<?, ?it/s]
# Índice gerado com sucesso!

# %%
chatbot = ChatBot(index)
chatbot.respond("Me resuma os resultados da magalu no útimo trimestre")
# Out:
# O Magalu não teria a escala, a abrangência e resultados mais resilientes sem isso.
#
# As mais de duas dezenas de operações adquiridas, além de outras desenvolvidas do zero como a Magalu Cloud, foram integradas e conectadas e parte delas se transformou em quatro pilares de geração de resultado: o Magalu Bank, em serviços financeiros, o Magalu Ads, em retail media e conteúdo, o Magalu Cloud, em Maas (tecnologia), e o Magalog, em logística. Netshoes, Época, Zattini, KaBum!, Aiqfome e Estante Virtual hoje estão 100% conectadas ao ecossistema, contribuem para seu fortalecimento ao mesmo tempo em que se beneficiam dele.
# Similaridade: [[0.0869909]]
# ---------------------------
# Ao longo do trimestre finalizamos também o aumento de capital na Luizacred no montante de R$300 milhões e recompramos cerca de R$100 milhões de dívida (referentes à 10ª emissão de debêntures). Com isso, o caixa líquido do Magalu ao término do trimestre alcançou R$1,8 bilhão.
#
# Tem Ali no Magalu: A parceria entre Magalu e AliExpress já está em operação.
# Similaridade: [[0.14134046]]
# ---------------------------
# Levando em consideração os últimos 12 meses, o EBITDA do Magalu atingiu 2,9 bilhões de reais e cresceu 40% comparado ao ano anterior. No mesmo período, o lucro líquido foi de 239 milhões de reais. É o quarto balanço consecutivo de resultado positivo – uma ratificação de nossa crença de que o Magalu deve ser, antes de mais nada, uma empresa lucrativa, a despeito das condições externas.
#
# Com a significativa evolução nos nossos resultados somada à melhoria do capital de giro, a geração de caixa operacional – um dos destaques desse trimestre – foi de 571 milhões de reais.
# Similaridade: [[0.08259931]]
# ---------------------------
# # Divulgação de Resultados
#
# # 3T24
#
# # TELECONFERÊNCIA DE RESULTADOS
#
# Teleconferência em Português com tradução simultânea para o inglês
#
# 08 de novembro de 2024 (sexta-feira)
#
# 09h00 – Horário de Brasília
#
# 07h00 – Horário Estados Unidos (EST)
#
# # Acesso Teleconferência
#
# Twitter: @ri_magalu
#
# # Relações com Investidores
#
#
# Similaridade: [[0.04209076]]
# ---------------------------
#
#
# Tel.: +55 11 3504-2727
#
# ri@magazineluiza.com.br
#
# # Sobre o Magazine Luiza
#
# Magazine Luiza, ou Magalu, é uma empresa de tecnologia e logística voltada para o varejo.
# Similaridade: [[0.03309598]]
# ---------------------------
# A posição de caixa total do Magalu em setembro foi de 6,6 bilhões de reais, um aumento de 162 milhões no trimestre – mesmo realizando recompra de cerca de 100 milhões de reais em debêntures.
#
# Para criar esse ecossistema (um termo banalizado no mercado, mas que faz todo sentido no nosso caso), fizemos mais de 20 aquisições ao longo dos últimos quatro anos – uma forma de acelerar tanto a diversidade de categorias de produtos oferecidas em nossa plataforma digital quanto de aumentar as receitas com serviços.
# Similaridade: [[0.06132783]]
# ---------------------------
# Contexto: O Magalu não teria a escala, a abrangência e resultados mais resilientes sem isso.
#
# As mais de duas dezenas de operações adquiridas, além de outras desenvolvidas do zero como a Magalu Cloud, foram integradas e conectadas e parte delas se transformou em quatro pilares de geração de resultado: o Magalu Bank, em serviços financeiros, o Magalu Ads, em retail media e conteúdo, o Magalu Cloud, em Maas (tecnologia), e o Magalog, em logística. Netshoes, Época, Zattini, KaBum!, Aiqfome e Estante Virtual hoje estão 100% conectadas ao ecossistema, contribuem para seu fortalecimento ao mesmo tempo em que se beneficiam dele.
# Ao longo do trimestre finalizamos também o aumento de capital na Luizacred no montante de R$300 milhões e recompramos cerca de R$100 milhões de dívida (referentes à 10ª emissão de debêntures). Com isso, o caixa líquido do Magalu ao término do trimestre alcançou R$1,8 bilhão.
#
# Tem Ali no Magalu: A parceria entre Magalu e AliExpress já está em operação.
# Levando em consideração os últimos 12 meses, o EBITDA do Magalu atingiu 2,9 bilhões de reais e cresceu 40% comparado ao ano anterior. No mesmo período, o lucro líquido foi de 239 milhões de reais. É o quarto balanço consecutivo de resultado positivo – uma ratificação de nossa crença de que o Magalu deve ser, antes de mais nada, uma empresa lucrativa, a despeito das condições externas.
#
# Com a significativa evolução nos nossos resultados somada à melhoria do capital de giro, a geração de caixa operacional – um dos destaques desse trimestre – foi de 571 milhões de reais.
# # Divulgação de Resultados
#
# # 3T24
#
# # TELECONFERÊNCIA DE RESULTADOS
#
# Teleconferência em Português com tradução simultânea para o inglês
#
# 08 de novembro de 2024 (sexta-feira)
#
# 09h00 – Horário de Brasília
#
# 07h00 – Horário Estados Unidos (EST)
#
# # Acesso Teleconferência
#
# Twitter: @ri_magalu
#
# # Relações com Investidores
#
#
#
#
# Tel.: +55 11 3504-2727
#
# ri@magazineluiza.com.br
#
# # Sobre o Magazine Luiza
#
# Magazine Luiza, ou Magalu, é uma empresa de tecnologia e logística voltada para o varejo.
# A posição de caixa total do Magalu em setembro foi de 6,6 bilhões de reais, um aumento de 162 milhões no trimestre – mesmo realizando recompra de cerca de 100 milhões de reais em debêntures.
#
# Para criar esse ecossistema (um termo banalizado no mercado, mas que faz todo sentido no nosso caso), fizemos mais de 20 aquisições ao longo dos últimos quatro anos – uma forma de acelerar tanto a diversidade de categorias de produtos oferecidas em nossa plataforma digital quanto de aumentar as receitas com serviços.
# Contexto: O Magalu não teria a escala, a abrangência e resultados mais resilientes sem isso.
#
# As mais de duas dezenas de operações adquiridas, além de outras desenvolvidas do zero como a Magalu Cloud, foram integradas e conectadas e parte delas se transformou em quatro pilares de geração de resultado: o Magalu Bank, em serviços financeiros, o Magalu Ads, em retail media e conteúdo, o Magalu Cloud, em Maas (tecnologia), e o Magalog, em logística. Netshoes, Época, Zattini, KaBum!, Aiqfome e Estante Virtual hoje estão 100% conectadas ao ecossistema, contribuem para seu fortalecimento ao mesmo tempo em que se beneficiam dele.
# Ao longo do trimestre finalizamos também o aumento de capital na Luizacred no montante de R$300 milhões e recompramos cerca de R$100 milhões de dívida (referentes à 10ª emissão de debêntures). Com isso, o caixa líquido do Magalu ao término do trimestre alcançou R$1,8 bilhão.
#
# Tem Ali no Magalu: A parceria entre Magalu e AliExpress já está em operação.
# Levando em consideração os últimos 12 meses, o EBITDA do Magalu atingiu 2,9 bilhões de reais e cresceu 40% comparado ao ano anterior. No mesmo período, o lucro líquido foi de 239 milhões de reais. É o quarto balanço consecutivo de resultado positivo – uma ratificação de nossa crença de que o Magalu deve ser, antes de mais nada, uma empresa lucrativa, a despeito das condições externas.
#
# Com a significativa evolução nos nossos resultados somada à melhoria do capital de giro, a geração de caixa operacional – um dos destaques desse trimestre – foi de 571 milhões de reais.
# # Divulgação de Resultados
#
# # 3T24
#
# # TELECONFERÊNCIA DE RESULTADOS
#
# Teleconferência em Português com tradução simultânea para o inglês
#
# 08 de novembro de 2024 (sexta-feira)
#
# 09h00 – Horário de Brasília
#
# 07h00 – Horário Estados Unidos (EST)
#
# # Acesso Teleconferência
#
# Twitter: @ri_magalu
#
# # Relações com Investidores
#
#
#
#
# Tel.: +55 11 3504-2727
#
# ri@magazineluiza.com.br
#
# # Sobre o Magazine Luiza
#
# Magazine Luiza, ou Magalu, é uma empresa de tecnologia e logística voltada para o varejo.
# A posição de caixa total do Magalu em setembro foi de 6,6 bilhões de reais, um aumento de 162 milhões no trimestre – mesmo realizando recompra de cerca de 100 milhões de reais em debêntures.
#
# Para criar esse ecossistema (um termo banalizado no mercado, mas que faz todo sentido no nosso caso), fizemos mais de 20 aquisições ao longo dos últimos quatro anos – uma forma de acelerar tanto a diversidade de categorias de produtos oferecidas em nossa plataforma digital quanto de aumentar as receitas com serviços.  || Pergunta: Me resuma os resultados da magalu no útimo trimestre
# ' No último trimestre, a Magalu apresentou um EBITDA de 2,9 bilhões de reais, com um crescimento de 40% em relação ao ano anterior. O lucro líquido foi de 239 milhões de reais, sendo o quarto balanço consecutivo de resultado positivo. A geração de caixa operacional foi de 571 milhões de reais. A posição de caixa total do Magalu em setembro foi de 6,6 bilhões de reais, com um aumento de 162 milhões no trimestre. A empresa também realizou uma recompra de cerca de 100 milhões de reais em debêntures.'

# %%
chatbot.interface()
# Out:
# * Running on local URL:  http://127.0.0.1:7860
#
# To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
# Essa parceria permitirá ao Magalu ampliar sua participação de mercado em categorias de tickets baixos por meio do marketplace e também alavancar as vendas do 1P para uma nova base de clientes.
#
# O Fulfillment já é responsável por 24% dos pedidos do marketplace, um significativo aumento de 10 p.p.
# Similaridade: [[0.18036443]]
# ---------------------------
# O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
# Similaridade: [[0.18429267]]
# ---------------------------
# # Crescimento das Vendas Totais (em %)
#
#
# Similaridade: [[0.07357475]]
# ---------------------------
# Crescimento das Vendas Mesmas Lojas Físicas
# Similaridade: [[0.06655925]]
# ---------------------------
# Crescimento do E-commerce Marketplace (3P)
# Similaridade: [[0.15973938]]
# ---------------------------
# Crescimento das Vendas Totais Lojas Físicas
# Similaridade: [[0.06655925]]
# ---------------------------
# Crescimento do E-commerce Total (1P+3P)
# Similaridade: [[0.06655925]]
# ---------------------------
# Crescimento do E-commerce Tradicional (1P)
# Similaridade: [[0.07357475]]
# ---------------------------
# Crescimento das Vendas Totais do Varejo
# Similaridade: [[0.14291973]]
# ---------------------------
#
#
# # Mix de Vendas Financiadas (em %)
#
#
# Similaridade: [[0.07357475]]
# ---------------------------
#
#
# No 3T24, a participação das vendas à vista aumentou de 33% para 36% comparada ao ano anterior. Esse aumento está associado ao crescimento da utilização do PIX, com destaque no KaBuM!, Netshoes e no Magalu, contribuindo para a atenuar o efeito das altas taxas de juros.
# Similaridade: [[0.09256709]]
# ---------------------------
# Ao optar pela migração para o Fulfillment, os sellers conseguem reduzir em média 40% os prazos de entrega e 20% os custos, dobrando sua taxa de conversão de vendas.
#
# O NPS Corporativo alcançou 80, um aumento de 13 pontos de janeiro a setembro deste ano, marcando a maior pontuação já obtida. Esse resultado histórico foi impulsionado pelo NPS do marketplace, que subiu para 75, aproximando-se dos níveis de satisfação excepcionais das Lojas e do 1P.
#
#
# Similaridade: [[0.06285538]]
# ---------------------------
# No 3T24, as vendas do e-commerce totalizaram R$11,0 bilhões. No e-commerce com estoque próprio (1P), as vendas foram de R$6,5 bilhões e cresceram 1,2%. No marketplace, as vendas atingiram R$4,5 bilhões no trimestre, com crescimento de 1,4%. Esse crescimento foi reflexo da performance do app, com 47,8 milhões de usuários ativos mensais, além da entrega mais rápida para 1P e 3P, a evolução da base de sellers e das novas categorias.
#
#
# Similaridade: [[0.222647]]
# ---------------------------
# Contexto: Essa parceria permitirá ao Magalu ampliar sua participação de mercado em categorias de tickets baixos por meio do marketplace e também alavancar as vendas do 1P para uma nova base de clientes.
#
# O Fulfillment já é responsável por 24% dos pedidos do marketplace, um significativo aumento de 10 p.p.
# O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
# # Crescimento das Vendas Totais (em %)
#
#
# Crescimento das Vendas Mesmas Lojas Físicas
# Crescimento do E-commerce Marketplace (3P)
# Crescimento das Vendas Totais Lojas Físicas
# Crescimento do E-commerce Total (1P+3P)
# Crescimento do E-commerce Tradicional (1P)
# Crescimento das Vendas Totais do Varejo
#
#
# # Mix de Vendas Financiadas (em %)
#
#
#
#
# No 3T24, a participação das vendas à vista aumentou de 33% para 36% comparada ao ano anterior. Esse aumento está associado ao crescimento da utilização do PIX, com destaque no KaBuM!, Netshoes e no Magalu, contribuindo para a atenuar o efeito das altas taxas de juros.
# Ao optar pela migração para o Fulfillment, os sellers conseguem reduzir em média 40% os prazos de entrega e 20% os custos, dobrando sua taxa de conversão de vendas.
#
# O NPS Corporativo alcançou 80, um aumento de 13 pontos de janeiro a setembro deste ano, marcando a maior pontuação já obtida. Esse resultado histórico foi impulsionado pelo NPS do marketplace, que subiu para 75, aproximando-se dos níveis de satisfação excepcionais das Lojas e do 1P.
#
#
# No 3T24, as vendas do e-commerce totalizaram R$11,0 bilhões. No e-commerce com estoque próprio (1P), as vendas foram de R$6,5 bilhões e cresceram 1,2%. No marketplace, as vendas atingiram R$4,5 bilhões no trimestre, com crescimento de 1,4%. Esse crescimento foi reflexo da performance do app, com 47,8 milhões de usuários ativos mensais, além da entrega mais rápida para 1P e 3P, a evolução da base de sellers e das novas categorias.
#
#
# Contexto: Essa parceria permitirá ao Magalu ampliar sua participação de mercado em categorias de tickets baixos por meio do marketplace e também alavancar as vendas do 1P para uma nova base de clientes.
#
# O Fulfillment já é responsável por 24% dos pedidos do marketplace, um significativo aumento de 10 p.p.
# O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
# # Crescimento das Vendas Totais (em %)
#
#
# Crescimento das Vendas Mesmas Lojas Físicas
# Crescimento do E-commerce Marketplace (3P)
# Crescimento das Vendas Totais Lojas Físicas
# Crescimento do E-commerce Total (1P+3P)
# Crescimento do E-commerce Tradicional (1P)
# Crescimento das Vendas Totais do Varejo
#
#
# # Mix de Vendas Financiadas (em %)
#
#
#
#
# No 3T24, a participação das vendas à vista aumentou de 33% para 36% comparada ao ano anterior. Esse aumento está associado ao crescimento da utilização do PIX, com destaque no KaBuM!, Netshoes e no Magalu, contribuindo para a atenuar o efeito das altas taxas de juros.
# Ao optar pela migração para o Fulfillment, os sellers conseguem reduzir em média 40% os prazos de entrega e 20% os custos, dobrando sua taxa de conversão de vendas.
#
# O NPS Corporativo alcançou 80, um aumento de 13 pontos de janeiro a setembro deste ano, marcando a maior pontuação já obtida. Esse resultado histórico foi impulsionado pelo NPS do marketplace, que subiu para 75, aproximando-se dos níveis de satisfação excepcionais das Lojas e do 1P.
#
#
# No 3T24, as vendas do e-commerce totalizaram R$11,0 bilhões. No e-commerce com estoque próprio (1P), as vendas foram de R$6,5 bilhões e cresceram 1,2%. No marketplace, as vendas atingiram R$4,5 bilhões no trimestre, com crescimento de 1,4%. Esse crescimento foi reflexo da performance do app, com 47,8 milhões de usuários ativos mensais, além da entrega mais rápida para 1P e 3P, a evolução da base de sellers e das novas categorias.
#
#  || Pergunta: Pode me resumir como foram as vendas do marketplace da magalu?
# O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
# Similaridade: [[0.15808857]]
# ---------------------------
# # Divulgação de Resultados 3T24
#
# # Destaques Financeiros do 3T24
#
# Crescimento de vendas combinado com aumento da rentabilidade. No 3T24, as vendas totais, incluindo lojas físicas, e-commerce com estoque próprio (1P) e marketplace (3P) cresceram 4,5% comparado ao mesmo período do ano anterior e totalizaram R$15,5 bilhões. Isso foi reflexo do aumento de 1,3% no e-commerce total e um crescimento de 13,3% nas lojas físicas, com forte ganho de marketshare.
#
# Marketplace atinge 41% das vendas online.
# Similaridade: [[0.12726575]]
# ---------------------------
# Entre outras coisas, o Luizalabs utiliza tecnologias como big data e machine learning para criar aplicativos para as diversas áreas da Companhia, como atendimento, logística, financeiro e gestão de estoque, com o objetivo de eliminar qualquer fricção no processo do varejo, melhorando a rentabilidade, os prazos de entrega e a experiência do cliente. A empresa tem estado na vanguarda da adoção do e-commerce na América Latina e a operação online, incluindo o marketplace, representa 71% das vendas totais.
# Similaridade: [[0.07649908]]
# ---------------------------
# No 3T24, as vendas do e-commerce totalizaram R$11,0 bilhões. No e-commerce com estoque próprio (1P), as vendas foram de R$6,5 bilhões e cresceram 1,2%. No marketplace, as vendas atingiram R$4,5 bilhões no trimestre, com crescimento de 1,4%. Esse crescimento foi reflexo da performance do app, com 47,8 milhões de usuários ativos mensais, além da entrega mais rápida para 1P e 3P, a evolução da base de sellers e das novas categorias.
#
#
# Similaridade: [[0.12829605]]
# ---------------------------
# Contexto: O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
# # Divulgação de Resultados 3T24
#
# # Destaques Financeiros do 3T24
#
# Crescimento de vendas combinado com aumento da rentabilidade. No 3T24, as vendas totais, incluindo lojas físicas, e-commerce com estoque próprio (1P) e marketplace (3P) cresceram 4,5% comparado ao mesmo período do ano anterior e totalizaram R$15,5 bilhões. Isso foi reflexo do aumento de 1,3% no e-commerce total e um crescimento de 13,3% nas lojas físicas, com forte ganho de marketshare.
#
# Marketplace atinge 41% das vendas online.
# Entre outras coisas, o Luizalabs utiliza tecnologias como big data e machine learning para criar aplicativos para as diversas áreas da Companhia, como atendimento, logística, financeiro e gestão de estoque, com o objetivo de eliminar qualquer fricção no processo do varejo, melhorando a rentabilidade, os prazos de entrega e a experiência do cliente. A empresa tem estado na vanguarda da adoção do e-commerce na América Latina e a operação online, incluindo o marketplace, representa 71% das vendas totais.
# No 3T24, as vendas do e-commerce totalizaram R$11,0 bilhões. No e-commerce com estoque próprio (1P), as vendas foram de R$6,5 bilhões e cresceram 1,2%. No marketplace, as vendas atingiram R$4,5 bilhões no trimestre, com crescimento de 1,4%. Esse crescimento foi reflexo da performance do app, com 47,8 milhões de usuários ativos mensais, além da entrega mais rápida para 1P e 3P, a evolução da base de sellers e das novas categorias.
#
#
# Contexto: O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
# # Divulgação de Resultados 3T24
#
# # Destaques Financeiros do 3T24
#
# Crescimento de vendas combinado com aumento da rentabilidade. No 3T24, as vendas totais, incluindo lojas físicas, e-commerce com estoque próprio (1P) e marketplace (3P) cresceram 4,5% comparado ao mesmo período do ano anterior e totalizaram R$15,5 bilhões. Isso foi reflexo do aumento de 1,3% no e-commerce total e um crescimento de 13,3% nas lojas físicas, com forte ganho de marketshare.
#
# Marketplace atinge 41% das vendas online.
# Entre outras coisas, o Luizalabs utiliza tecnologias como big data e machine learning para criar aplicativos para as diversas áreas da Companhia, como atendimento, logística, financeiro e gestão de estoque, com o objetivo de eliminar qualquer fricção no processo do varejo, melhorando a rentabilidade, os prazos de entrega e a experiência do cliente. A empresa tem estado na vanguarda da adoção do e-commerce na América Latina e a operação online, incluindo o marketplace, representa 71% das vendas totais.
# No 3T24, as vendas do e-commerce totalizaram R$11,0 bilhões. No e-commerce com estoque próprio (1P), as vendas foram de R$6,5 bilhões e cresceram 1,2%. No marketplace, as vendas atingiram R$4,5 bilhões no trimestre, com crescimento de 1,4%. Esse crescimento foi reflexo da performance do app, com 47,8 milhões de usuários ativos mensais, além da entrega mais rápida para 1P e 3P, a evolução da base de sellers e das novas categorias.
#
#  || Pergunta: E o e-commerce?
# Menos de três meses depois, milhares de produtos cross border da linha Choice do AliExpress passaram a ser vendidos por meio dos canais digitais do Magalu. Ao mesmo tempo, itens 1P do Magalu (estoque próprio) começaram a ser oferecidos na plataforma do AliExpress no Brasil. Foi um movimento típico de união de competências que faz com que todos saiam ganhando.
# Similaridade: [[0.06620221]]
# ---------------------------
# De cadeiras gamer a camisas de time de futebol. Para suportar o crescimento da participação nesse mercado, a companhia vem investindo na evolução de seu sistema de fulfillment multicanal e da Agência Magalu, ao usar suas 1.245 lojas físicas para a retirada de produtos comprados nos canais digitais (Retira Loja), a entrega de itens vendidos por parte dos sellers do marketplace (drop-off) e o ship-from-store.
#
# Como o acordo com o AliExpress se integra à nossa estratégia de expansão e diversificação de motores de resultado? Fortalecendo nossas vendas digitais – e, particularmente, nosso 3P – com itens com tíquetes de até 200 reais, um mercado que surfa a onda do aumento de renda da população e no qual os asiáticos são reconhecidamente competitivos.
#
#
# Similaridade: [[0.05150785]]
# ---------------------------
# Ao longo do trimestre finalizamos também o aumento de capital na Luizacred no montante de R$300 milhões e recompramos cerca de R$100 milhões de dívida (referentes à 10ª emissão de debêntures). Com isso, o caixa líquido do Magalu ao término do trimestre alcançou R$1,8 bilhão.
#
# Tem Ali no Magalu: A parceria entre Magalu e AliExpress já está em operação.
# Similaridade: [[0.06795043]]
# ---------------------------
# Essa parceria permitirá ao Magalu ampliar sua participação de mercado em categorias de tickets baixos por meio do marketplace e também alavancar as vendas do 1P para uma nova base de clientes.
#
# O Fulfillment já é responsável por 24% dos pedidos do marketplace, um significativo aumento de 10 p.p.
# Similaridade: [[0.0243368]]
# ---------------------------
# e com a Época Cosméticos, que já fazia parte de nosso portfólio, avançamos significativamente na venda de categorias com tíquetes na faixa intermediária, de 200 a 1.000 reais. Passamos a vender de batom a chuteiras.
# Similaridade: [[0.05982396]]
# ---------------------------
# Contexto: Menos de três meses depois, milhares de produtos cross border da linha Choice do AliExpress passaram a ser vendidos por meio dos canais digitais do Magalu. Ao mesmo tempo, itens 1P do Magalu (estoque próprio) começaram a ser oferecidos na plataforma do AliExpress no Brasil. Foi um movimento típico de união de competências que faz com que todos saiam ganhando.
# De cadeiras gamer a camisas de time de futebol. Para suportar o crescimento da participação nesse mercado, a companhia vem investindo na evolução de seu sistema de fulfillment multicanal e da Agência Magalu, ao usar suas 1.245 lojas físicas para a retirada de produtos comprados nos canais digitais (Retira Loja), a entrega de itens vendidos por parte dos sellers do marketplace (drop-off) e o ship-from-store.
#
# Como o acordo com o AliExpress se integra à nossa estratégia de expansão e diversificação de motores de resultado? Fortalecendo nossas vendas digitais – e, particularmente, nosso 3P – com itens com tíquetes de até 200 reais, um mercado que surfa a onda do aumento de renda da população e no qual os asiáticos são reconhecidamente competitivos.
#
#
# Ao longo do trimestre finalizamos também o aumento de capital na Luizacred no montante de R$300 milhões e recompramos cerca de R$100 milhões de dívida (referentes à 10ª emissão de debêntures). Com isso, o caixa líquido do Magalu ao término do trimestre alcançou R$1,8 bilhão.
#
# Tem Ali no Magalu: A parceria entre Magalu e AliExpress já está em operação.
# Essa parceria permitirá ao Magalu ampliar sua participação de mercado em categorias de tickets baixos por meio do marketplace e também alavancar as vendas do 1P para uma nova base de clientes.
#
# O Fulfillment já é responsável por 24% dos pedidos do marketplace, um significativo aumento de 10 p.p.
# e com a Época Cosméticos, que já fazia parte de nosso portfólio, avançamos significativamente na venda de categorias com tíquetes na faixa intermediária, de 200 a 1.000 reais. Passamos a vender de batom a chuteiras.
# Contexto: Menos de três meses depois, milhares de produtos cross border da linha Choice do AliExpress passaram a ser vendidos por meio dos canais digitais do Magalu. Ao mesmo tempo, itens 1P do Magalu (estoque próprio) começaram a ser oferecidos na plataforma do AliExpress no Brasil. Foi um movimento típico de união de competências que faz com que todos saiam ganhando.
# De cadeiras gamer a camisas de time de futebol. Para suportar o crescimento da participação nesse mercado, a companhia vem investindo na evolução de seu sistema de fulfillment multicanal e da Agência Magalu, ao usar suas 1.245 lojas físicas para a retirada de produtos comprados nos canais digitais (Retira Loja), a entrega de itens vendidos por parte dos sellers do marketplace (drop-off) e o ship-from-store.
#
# Como o acordo com o AliExpress se integra à nossa estratégia de expansão e diversificação de motores de resultado? Fortalecendo nossas vendas digitais – e, particularmente, nosso 3P – com itens com tíquetes de até 200 reais, um mercado que surfa a onda do aumento de renda da população e no qual os asiáticos são reconhecidamente competitivos.
#
#
# Ao longo do trimestre finalizamos também o aumento de capital na Luizacred no montante de R$300 milhões e recompramos cerca de R$100 milhões de dívida (referentes à 10ª emissão de debêntures). Com isso, o caixa líquido do Magalu ao término do trimestre alcançou R$1,8 bilhão.
#
# Tem Ali no Magalu: A parceria entre Magalu e AliExpress já está em operação.
# Essa parceria permitirá ao Magalu ampliar sua participação de mercado em categorias de tickets baixos por meio do marketplace e também alavancar as vendas do 1P para uma nova base de clientes.
#
# O Fulfillment já é responsável por 24% dos pedidos do marketplace, um significativo aumento de 10 p.p.
# e com a Época Cosméticos, que já fazia parte de nosso portfólio, avançamos significativamente na venda de categorias com tíquetes na faixa intermediária, de 200 a 1.000 reais. Passamos a vender de batom a chuteiras.  || Pergunta: Pode me falar  sobre a parceria com a aliexpress
# Ao longo do trimestre finalizamos também o aumento de capital na Luizacred no montante de R$300 milhões e recompramos cerca de R$100 milhões de dívida (referentes à 10ª emissão de debêntures). Com isso, o caixa líquido do Magalu ao término do trimestre alcançou R$1,8 bilhão.
#
# Tem Ali no Magalu: A parceria entre Magalu e AliExpress já está em operação.
# Similaridade: [[0.15490668]]
# ---------------------------
# O Magalu não teria a escala, a abrangência e resultados mais resilientes sem isso.
#
# As mais de duas dezenas de operações adquiridas, além de outras desenvolvidas do zero como a Magalu Cloud, foram integradas e conectadas e parte delas se transformou em quatro pilares de geração de resultado: o Magalu Bank, em serviços financeiros, o Magalu Ads, em retail media e conteúdo, o Magalu Cloud, em Maas (tecnologia), e o Magalog, em logística. Netshoes, Época, Zattini, KaBum!, Aiqfome e Estante Virtual hoje estão 100% conectadas ao ecossistema, contribuem para seu fortalecimento ao mesmo tempo em que se beneficiam dele.
# Similaridade: [[0.0873062]]
# ---------------------------
# Da base total, 20% das lojas estão em processo de maturação.
#
# # Evolução do Número de Lojas (em quantidade)
#
#
# Similaridade: [[0.09193998]]
# ---------------------------
#
#
# # Idade Média das Lojas (em quantidade de lojas)
#
#
# Similaridade: [[0.15231416]]
# ---------------------------
#
#
# No 3T24, as vendas totais do Magalu cresceram 4,5%, reflexo do aumento de 1,3% no e-commerce total e pelo crescimento de 13,3% nas lojas físicas (crescimento no conceito mesmas lojas de 15,2%).
# Similaridade: [[0.10165346]]
# ---------------------------
# A posição de caixa total do Magalu em setembro foi de 6,6 bilhões de reais, um aumento de 162 milhões no trimestre – mesmo realizando recompra de cerca de 100 milhões de reais em debêntures.
#
# Para criar esse ecossistema (um termo banalizado no mercado, mas que faz todo sentido no nosso caso), fizemos mais de 20 aquisições ao longo dos últimos quatro anos – uma forma de acelerar tanto a diversidade de categorias de produtos oferecidas em nossa plataforma digital quanto de aumentar as receitas com serviços.
# Similaridade: [[0.04705651]]
# ---------------------------
# Menos de três meses depois, milhares de produtos cross border da linha Choice do AliExpress passaram a ser vendidos por meio dos canais digitais do Magalu. Ao mesmo tempo, itens 1P do Magalu (estoque próprio) começaram a ser oferecidos na plataforma do AliExpress no Brasil. Foi um movimento típico de união de competências que faz com que todos saiam ganhando.
# Similaridade: [[0.07250583]]
# ---------------------------
# Contexto: Ao longo do trimestre finalizamos também o aumento de capital na Luizacred no montante de R$300 milhões e recompramos cerca de R$100 milhões de dívida (referentes à 10ª emissão de debêntures). Com isso, o caixa líquido do Magalu ao término do trimestre alcançou R$1,8 bilhão.
#
# Tem Ali no Magalu: A parceria entre Magalu e AliExpress já está em operação.
# O Magalu não teria a escala, a abrangência e resultados mais resilientes sem isso.
#
# As mais de duas dezenas de operações adquiridas, além de outras desenvolvidas do zero como a Magalu Cloud, foram integradas e conectadas e parte delas se transformou em quatro pilares de geração de resultado: o Magalu Bank, em serviços financeiros, o Magalu Ads, em retail media e conteúdo, o Magalu Cloud, em Maas (tecnologia), e o Magalog, em logística. Netshoes, Época, Zattini, KaBum!, Aiqfome e Estante Virtual hoje estão 100% conectadas ao ecossistema, contribuem para seu fortalecimento ao mesmo tempo em que se beneficiam dele.
# Da base total, 20% das lojas estão em processo de maturação.
#
# # Evolução do Número de Lojas (em quantidade)
#
#
#
#
# # Idade Média das Lojas (em quantidade de lojas)
#
#
#
#
# No 3T24, as vendas totais do Magalu cresceram 4,5%, reflexo do aumento de 1,3% no e-commerce total e pelo crescimento de 13,3% nas lojas físicas (crescimento no conceito mesmas lojas de 15,2%).
# A posição de caixa total do Magalu em setembro foi de 6,6 bilhões de reais, um aumento de 162 milhões no trimestre – mesmo realizando recompra de cerca de 100 milhões de reais em debêntures.
#
# Para criar esse ecossistema (um termo banalizado no mercado, mas que faz todo sentido no nosso caso), fizemos mais de 20 aquisições ao longo dos últimos quatro anos – uma forma de acelerar tanto a diversidade de categorias de produtos oferecidas em nossa plataforma digital quanto de aumentar as receitas com serviços.
# Menos de três meses depois, milhares de produtos cross border da linha Choice do AliExpress passaram a ser vendidos por meio dos canais digitais do Magalu. Ao mesmo tempo, itens 1P do Magalu (estoque próprio) começaram a ser oferecidos na plataforma do AliExpress no Brasil. Foi um movimento típico de união de competências que faz com que todos saiam ganhando.
# Contexto: Ao longo do trimestre finalizamos também o aumento de capital na Luizacred no montante de R$300 milhões e recompramos cerca de R$100 milhões de dívida (referentes à 10ª emissão de debêntures). Com isso, o caixa líquido do Magalu ao término do trimestre alcançou R$1,8 bilhão.
#
# Tem Ali no Magalu: A parceria entre Magalu e AliExpress já está em operação.
# O Magalu não teria a escala, a abrangência e resultados mais resilientes sem isso.
#
# As mais de duas dezenas de operações adquiridas, além de outras desenvolvidas do zero como a Magalu Cloud, foram integradas e conectadas e parte delas se transformou em quatro pilares de geração de resultado: o Magalu Bank, em serviços financeiros, o Magalu Ads, em retail media e conteúdo, o Magalu Cloud, em Maas (tecnologia), e o Magalog, em logística. Netshoes, Época, Zattini, KaBum!, Aiqfome e Estante Virtual hoje estão 100% conectadas ao ecossistema, contribuem para seu fortalecimento ao mesmo tempo em que se beneficiam dele.
# Da base total, 20% das lojas estão em processo de maturação.
#
# # Evolução do Número de Lojas (em quantidade)
#
#
#
#
# # Idade Média das Lojas (em quantidade de lojas)
#
#
#
#
# No 3T24, as vendas totais do Magalu cresceram 4,5%, reflexo do aumento de 1,3% no e-commerce total e pelo crescimento de 13,3% nas lojas físicas (crescimento no conceito mesmas lojas de 15,2%).
# A posição de caixa total do Magalu em setembro foi de 6,6 bilhões de reais, um aumento de 162 milhões no trimestre – mesmo realizando recompra de cerca de 100 milhões de reais em debêntures.
#
# Para criar esse ecossistema (um termo banalizado no mercado, mas que faz todo sentido no nosso caso), fizemos mais de 20 aquisições ao longo dos últimos quatro anos – uma forma de acelerar tanto a diversidade de categorias de produtos oferecidas em nossa plataforma digital quanto de aumentar as receitas com serviços.
# Menos de três meses depois, milhares de produtos cross border da linha Choice do AliExpress passaram a ser vendidos por meio dos canais digitais do Magalu. Ao mesmo tempo, itens 1P do Magalu (estoque próprio) começaram a ser oferecidos na plataforma do AliExpress no Brasil. Foi um movimento típico de união de competências que faz com que todos saiam ganhando.  || Pergunta: A magalu encerrou o trimestre com quantas lojas?
# O Magalu não teria a escala, a abrangência e resultados mais resilientes sem isso.
#
# As mais de duas dezenas de operações adquiridas, além de outras desenvolvidas do zero como a Magalu Cloud, foram integradas e conectadas e parte delas se transformou em quatro pilares de geração de resultado: o Magalu Bank, em serviços financeiros, o Magalu Ads, em retail media e conteúdo, o Magalu Cloud, em Maas (tecnologia), e o Magalog, em logística. Netshoes, Época, Zattini, KaBum!, Aiqfome e Estante Virtual hoje estão 100% conectadas ao ecossistema, contribuem para seu fortalecimento ao mesmo tempo em que se beneficiam dele.
# Similaridade: [[0.10940867]]
# ---------------------------
# # Divulgação de Resultados
#
# # 3T24
#
# # ANEXO VII
#
# # MAGALUBANK
#
# As iniciativas do MagaluBank integram soluções financeiras para clientes e sellers. Entre os serviços oferecidos, estão subadquirência, conta digital, cartão de crédito, CDC, seguros e empréstimos para pessoas físicas e jurídicas.
#
#
# Similaridade: [[0.04247934]]
# ---------------------------
# Menos de três meses depois, milhares de produtos cross border da linha Choice do AliExpress passaram a ser vendidos por meio dos canais digitais do Magalu. Ao mesmo tempo, itens 1P do Magalu (estoque próprio) começaram a ser oferecidos na plataforma do AliExpress no Brasil. Foi um movimento típico de união de competências que faz com que todos saiam ganhando.
# Similaridade: [[0.09352699]]
# ---------------------------
# # Divulgação de Resultados
#
# # 3T24
#
# # MENSAGEM DA DIRETORIA
#
# Em 2025, a atual gestão completará dez anos à frente da liderança do Magalu. Esse período, historicamente intenso e acelerado, é marcado por dois ciclos estratégicos que transformaram a companhia e contribuíram para fazer com chegássemos até aqui como um negócio de mais de 60 bilhões de reais de vendas, 36 milhões de clientes ativos e quase meio bilhão de visitas mensais em seus canais digitais.
#
#
# Similaridade: [[0.09102741]]
# ---------------------------
# # Divulgação de Resultados
#
# # 3T24
#
# # DESEMPENHO OPERACIONAL E FINANCEIRO
#
# O Magalu encerrou o 3T24 com 1.245 lojas, sendo 1.015 convencionais e 230 virtuais. No 3T24, a Companhia encerrou a operação de 1 loja virtual.
# Similaridade: [[0.46570736]]
# ---------------------------
# Contexto: O Magalu não teria a escala, a abrangência e resultados mais resilientes sem isso.
#
# As mais de duas dezenas de operações adquiridas, além de outras desenvolvidas do zero como a Magalu Cloud, foram integradas e conectadas e parte delas se transformou em quatro pilares de geração de resultado: o Magalu Bank, em serviços financeiros, o Magalu Ads, em retail media e conteúdo, o Magalu Cloud, em Maas (tecnologia), e o Magalog, em logística. Netshoes, Época, Zattini, KaBum!, Aiqfome e Estante Virtual hoje estão 100% conectadas ao ecossistema, contribuem para seu fortalecimento ao mesmo tempo em que se beneficiam dele.
# # Divulgação de Resultados
#
# # 3T24
#
# # ANEXO VII
#
# # MAGALUBANK
#
# As iniciativas do MagaluBank integram soluções financeiras para clientes e sellers. Entre os serviços oferecidos, estão subadquirência, conta digital, cartão de crédito, CDC, seguros e empréstimos para pessoas físicas e jurídicas.
#
#
# Menos de três meses depois, milhares de produtos cross border da linha Choice do AliExpress passaram a ser vendidos por meio dos canais digitais do Magalu. Ao mesmo tempo, itens 1P do Magalu (estoque próprio) começaram a ser oferecidos na plataforma do AliExpress no Brasil. Foi um movimento típico de união de competências que faz com que todos saiam ganhando.
# # Divulgação de Resultados
#
# # 3T24
#
# # MENSAGEM DA DIRETORIA
#
# Em 2025, a atual gestão completará dez anos à frente da liderança do Magalu. Esse período, historicamente intenso e acelerado, é marcado por dois ciclos estratégicos que transformaram a companhia e contribuíram para fazer com chegássemos até aqui como um negócio de mais de 60 bilhões de reais de vendas, 36 milhões de clientes ativos e quase meio bilhão de visitas mensais em seus canais digitais.
#
#
# # Divulgação de Resultados
#
# # 3T24
#
# # DESEMPENHO OPERACIONAL E FINANCEIRO
#
# O Magalu encerrou o 3T24 com 1.245 lojas, sendo 1.015 convencionais e 230 virtuais. No 3T24, a Companhia encerrou a operação de 1 loja virtual.
# Contexto: O Magalu não teria a escala, a abrangência e resultados mais resilientes sem isso.
#
# As mais de duas dezenas de operações adquiridas, além de outras desenvolvidas do zero como a Magalu Cloud, foram integradas e conectadas e parte delas se transformou em quatro pilares de geração de resultado: o Magalu Bank, em serviços financeiros, o Magalu Ads, em retail media e conteúdo, o Magalu Cloud, em Maas (tecnologia), e o Magalog, em logística. Netshoes, Época, Zattini, KaBum!, Aiqfome e Estante Virtual hoje estão 100% conectadas ao ecossistema, contribuem para seu fortalecimento ao mesmo tempo em que se beneficiam dele.
# # Divulgação de Resultados
#
# # 3T24
#
# # ANEXO VII
#
# # MAGALUBANK
#
# As iniciativas do MagaluBank integram soluções financeiras para clientes e sellers. Entre os serviços oferecidos, estão subadquirência, conta digital, cartão de crédito, CDC, seguros e empréstimos para pessoas físicas e jurídicas.
#
#
# Menos de três meses depois, milhares de produtos cross border da linha Choice do AliExpress passaram a ser vendidos por meio dos canais digitais do Magalu. Ao mesmo tempo, itens 1P do Magalu (estoque próprio) começaram a ser oferecidos na plataforma do AliExpress no Brasil. Foi um movimento típico de união de competências que faz com que todos saiam ganhando.
# # Divulgação de Resultados
#
# # 3T24
#
# # MENSAGEM DA DIRETORIA
#
# Em 2025, a atual gestão completará dez anos à frente da liderança do Magalu. Esse período, historicamente intenso e acelerado, é marcado por dois ciclos estratégicos que transformaram a companhia e contribuíram para fazer com chegássemos até aqui como um negócio de mais de 60 bilhões de reais de vendas, 36 milhões de clientes ativos e quase meio bilhão de visitas mensais em seus canais digitais.
#
#
# # Divulgação de Resultados
#
# # 3T24
#
# # DESEMPENHO OPERACIONAL E FINANCEIRO
#
# O Magalu encerrou o 3T24 com 1.245 lojas, sendo 1.015 convencionais e 230 virtuais. No 3T24, a Companhia encerrou a operação de 1 loja virtual.  || Pergunta: O Magalu encerrou o 3T24 com ...
# Nos 9M24, a despesa financeira líquida foi de R$910,1 milhões e representou 3,3% da receita líquida.
#
# # RESULTADO FINANCEIRO (em R$ milhões)
#
#
# Similaridade: [[0.16171378]]
# ---------------------------
# Juros de Empréstimos e Financiamentos
# Similaridade: [[0.11521554]]
# ---------------------------
# Juros de Antecipações de Cartão de Terceiros
# Similaridade: [[0.22126516]]
# ---------------------------
# Juros de Antecipações de Cartão Luiza
# Similaridade: [[0.17578608]]
# ---------------------------
# Rendimento de Aplicações Financeiras
# Similaridade: [[0.11521554]]
# ---------------------------
#
#
# # Lucro líquido
#
# No 3T24, o lucro líquido contábil foi de R$102,4 milhões, melhorando significativamente em relação aos últimos trimestres em função da eficiência operacional e da significativa diluição das despesas financeiras. Na visão ajustada, ou seja, desconsiderando os efeitos não recorrentes, o lucro líquido ajustado foi de R$70,2 milhões.
# Similaridade: [[0.1130144]]
# ---------------------------
# O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
# Similaridade: [[0.16598063]]
# ---------------------------
# Passamos a jogar, no online, o jogo do varejo impulsionado pelo aumento da renda da população, um cenário que já vinha beneficiando o desempenho de nossas lojas físicas. No terceiro trimestre de 2024, as vendas pelo critério de same store sales (SSS) avançaram 15%.
# Similaridade: [[0.13046388]]
# ---------------------------
# # Crescimento das Vendas Totais (em %)
#
#
# Similaridade: [[0.10163067]]
# ---------------------------
# Crescimento das Vendas Mesmas Lojas Físicas
# Similaridade: [[0.09193998]]
# ---------------------------
# Crescimento das Vendas Totais Lojas Físicas
# Similaridade: [[0.09193998]]
# ---------------------------
# Crescimento das Vendas Totais do Varejo
# Similaridade: [[0.09193998]]
# ---------------------------
#
#
# # Mix de Vendas Financiadas (em %)
#
#
# Similaridade: [[0.22576485]]
# ---------------------------
#
#
# No 3T24, a participação das vendas à vista aumentou de 33% para 36% comparada ao ano anterior. Esse aumento está associado ao crescimento da utilização do PIX, com destaque no KaBuM!, Netshoes e no Magalu, contribuindo para a atenuar o efeito das altas taxas de juros.
# Similaridade: [[0.13205459]]
# ---------------------------
# e com a Época Cosméticos, que já fazia parte de nosso portfólio, avançamos significativamente na venda de categorias com tíquetes na faixa intermediária, de 200 a 1.000 reais. Passamos a vender de batom a chuteiras.
# Similaridade: [[0.22572582]]
# ---------------------------
# Contexto: Nos 9M24, a despesa financeira líquida foi de R$910,1 milhões e representou 3,3% da receita líquida.
#
# # RESULTADO FINANCEIRO (em R$ milhões)
#
#
# Juros de Empréstimos e Financiamentos
# Juros de Antecipações de Cartão de Terceiros
# Juros de Antecipações de Cartão Luiza
# Rendimento de Aplicações Financeiras
#
#
# # Lucro líquido
#
# No 3T24, o lucro líquido contábil foi de R$102,4 milhões, melhorando significativamente em relação aos últimos trimestres em função da eficiência operacional e da significativa diluição das despesas financeiras. Na visão ajustada, ou seja, desconsiderando os efeitos não recorrentes, o lucro líquido ajustado foi de R$70,2 milhões.
# O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
# Passamos a jogar, no online, o jogo do varejo impulsionado pelo aumento da renda da população, um cenário que já vinha beneficiando o desempenho de nossas lojas físicas. No terceiro trimestre de 2024, as vendas pelo critério de same store sales (SSS) avançaram 15%.
# # Crescimento das Vendas Totais (em %)
#
#
# Crescimento das Vendas Mesmas Lojas Físicas
# Crescimento das Vendas Totais Lojas Físicas
# Crescimento das Vendas Totais do Varejo
#
#
# # Mix de Vendas Financiadas (em %)
#
#
#
#
# No 3T24, a participação das vendas à vista aumentou de 33% para 36% comparada ao ano anterior. Esse aumento está associado ao crescimento da utilização do PIX, com destaque no KaBuM!, Netshoes e no Magalu, contribuindo para a atenuar o efeito das altas taxas de juros.
# e com a Época Cosméticos, que já fazia parte de nosso portfólio, avançamos significativamente na venda de categorias com tíquetes na faixa intermediária, de 200 a 1.000 reais. Passamos a vender de batom a chuteiras.
# Contexto: Nos 9M24, a despesa financeira líquida foi de R$910,1 milhões e representou 3,3% da receita líquida.
#
# # RESULTADO FINANCEIRO (em R$ milhões)
#
#
# Juros de Empréstimos e Financiamentos
# Juros de Antecipações de Cartão de Terceiros
# Juros de Antecipações de Cartão Luiza
# Rendimento de Aplicações Financeiras
#
#
# # Lucro líquido
#
# No 3T24, o lucro líquido contábil foi de R$102,4 milhões, melhorando significativamente em relação aos últimos trimestres em função da eficiência operacional e da significativa diluição das despesas financeiras. Na visão ajustada, ou seja, desconsiderando os efeitos não recorrentes, o lucro líquido ajustado foi de R$70,2 milhões.
# O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
# Passamos a jogar, no online, o jogo do varejo impulsionado pelo aumento da renda da população, um cenário que já vinha beneficiando o desempenho de nossas lojas físicas. No terceiro trimestre de 2024, as vendas pelo critério de same store sales (SSS) avançaram 15%.
# # Crescimento das Vendas Totais (em %)
#
#
# Crescimento das Vendas Mesmas Lojas Físicas
# Crescimento das Vendas Totais Lojas Físicas
# Crescimento das Vendas Totais do Varejo
#
#
# # Mix de Vendas Financiadas (em %)
#
#
#
#
# No 3T24, a participação das vendas à vista aumentou de 33% para 36% comparada ao ano anterior. Esse aumento está associado ao crescimento da utilização do PIX, com destaque no KaBuM!, Netshoes e no Magalu, contribuindo para a atenuar o efeito das altas taxas de juros.
# e com a Época Cosméticos, que já fazia parte de nosso portfólio, avançamos significativamente na venda de categorias com tíquetes na faixa intermediária, de 200 a 1.000 reais. Passamos a vender de batom a chuteiras.  || Pergunta: De quanto foi a despesa com vendas?
# e com a Época Cosméticos, que já fazia parte de nosso portfólio, avançamos significativamente na venda de categorias com tíquetes na faixa intermediária, de 200 a 1.000 reais. Passamos a vender de batom a chuteiras.
# Similaridade: [[0.13262275]]
# ---------------------------
# Despesas Financeiras
# Similaridade: [[0.22028815]]
# ---------------------------
# Outras Despesas e Impostos
# Similaridade: [[0.17077611]]
# ---------------------------
#
#
# # Lucro líquido
#
# No 3T24, o lucro líquido contábil foi de R$102,4 milhões, melhorando significativamente em relação aos últimos trimestres em função da eficiência operacional e da significativa diluição das despesas financeiras. Na visão ajustada, ou seja, desconsiderando os efeitos não recorrentes, o lucro líquido ajustado foi de R$70,2 milhões.
# Similaridade: [[0.03290537]]
# ---------------------------
# O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
# Similaridade: [[0.09750712]]
# ---------------------------
#  Despesas Operacionais
#
#
# Similaridade: [[0.22028815]]
# ---------------------------
# Despesas com Vendas
# Similaridade: [[0.41120706]]
# ---------------------------
# Despesas Gerais e Administrativas
# Similaridade: [[0.17077611]]
# ---------------------------
# Total de Despesas Operacionais
# Similaridade: [[0.14438356]]
# ---------------------------
# Despesas Operacionais / Vendas Totais
# Similaridade: [[0.14438356]]
# ---------------------------
#
#
# # Despesas com Vendas
#
# No 3T24, as despesas com vendas totalizaram R$1,7 bilhão, representando 19,2% da receita líquida. Isso corresponde a uma redução de 0,9 p.p.
# Similaridade: [[0.33581954]]
# ---------------------------
# # Divulgação de Resultados 3T24
#
# # Destaques Financeiros do 3T24
#
# Crescimento de vendas combinado com aumento da rentabilidade. No 3T24, as vendas totais, incluindo lojas físicas, e-commerce com estoque próprio (1P) e marketplace (3P) cresceram 4,5% comparado ao mesmo período do ano anterior e totalizaram R$15,5 bilhões. Isso foi reflexo do aumento de 1,3% no e-commerce total e um crescimento de 13,3% nas lojas físicas, com forte ganho de marketshare.
#
# Marketplace atinge 41% das vendas online.
# Similaridade: [[0.10560055]]
# ---------------------------
# Contexto: e com a Época Cosméticos, que já fazia parte de nosso portfólio, avançamos significativamente na venda de categorias com tíquetes na faixa intermediária, de 200 a 1.000 reais. Passamos a vender de batom a chuteiras.
# Despesas Financeiras
# Outras Despesas e Impostos
#
#
# # Lucro líquido
#
# No 3T24, o lucro líquido contábil foi de R$102,4 milhões, melhorando significativamente em relação aos últimos trimestres em função da eficiência operacional e da significativa diluição das despesas financeiras. Na visão ajustada, ou seja, desconsiderando os efeitos não recorrentes, o lucro líquido ajustado foi de R$70,2 milhões.
# O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
#  Despesas Operacionais
#
#
# Despesas com Vendas
# Despesas Gerais e Administrativas
# Total de Despesas Operacionais
# Despesas Operacionais / Vendas Totais
#
#
# # Despesas com Vendas
#
# No 3T24, as despesas com vendas totalizaram R$1,7 bilhão, representando 19,2% da receita líquida. Isso corresponde a uma redução de 0,9 p.p.
# # Divulgação de Resultados 3T24
#
# # Destaques Financeiros do 3T24
#
# Crescimento de vendas combinado com aumento da rentabilidade. No 3T24, as vendas totais, incluindo lojas físicas, e-commerce com estoque próprio (1P) e marketplace (3P) cresceram 4,5% comparado ao mesmo período do ano anterior e totalizaram R$15,5 bilhões. Isso foi reflexo do aumento de 1,3% no e-commerce total e um crescimento de 13,3% nas lojas físicas, com forte ganho de marketshare.
#
# Marketplace atinge 41% das vendas online.
# Contexto: e com a Época Cosméticos, que já fazia parte de nosso portfólio, avançamos significativamente na venda de categorias com tíquetes na faixa intermediária, de 200 a 1.000 reais. Passamos a vender de batom a chuteiras.
# Despesas Financeiras
# Outras Despesas e Impostos
#
#
# # Lucro líquido
#
# No 3T24, o lucro líquido contábil foi de R$102,4 milhões, melhorando significativamente em relação aos últimos trimestres em função da eficiência operacional e da significativa diluição das despesas financeiras. Na visão ajustada, ou seja, desconsiderando os efeitos não recorrentes, o lucro líquido ajustado foi de R$70,2 milhões.
# O e-commerce atingiu R$11 bilhões em vendas no período. As vendas no e-commerce com estoque próprio totalizaram R$6,5 bilhões, e o DIFAL totalmente repassado contribuiu para a expansão da margem bruta. Já as vendas do marketplace alcançaram R$4,5 bilhões no mesmo período e representaram 41% das vendas online.
#
# A margem bruta atingiu 31,5%, crescendo de 1,1 p.p.
#  Despesas Operacionais
#
#
# Despesas com Vendas
# Despesas Gerais e Administrativas
# Total de Despesas Operacionais
# Despesas Operacionais / Vendas Totais
#
#
# # Despesas com Vendas
#
# No 3T24, as despesas com vendas totalizaram R$1,7 bilhão, representando 19,2% da receita líquida. Isso corresponde a uma redução de 0,9 p.p.
# # Divulgação de Resultados 3T24
#
# # Destaques Financeiros do 3T24
#
# Crescimento de vendas combinado com aumento da rentabilidade. No 3T24, as vendas totais, incluindo lojas físicas, e-commerce com estoque próprio (1P) e marketplace (3P) cresceram 4,5% comparado ao mesmo período do ano anterior e totalizaram R$15,5 bilhões. Isso foi reflexo do aumento de 1,3% no e-commerce total e um crescimento de 13,3% nas lojas físicas, com forte ganho de marketshare.
#
# Marketplace atinge 41% das vendas online.  || Pergunta: as  despesas  com  venda ...
# Contexto:
# Contexto:  || Pergunta: Obrigada!
# Keyboard interruption in main thread... closing server.

# %% [markdown]
# # Teste llama-parser

# %%
# bring in dependencies
from llama_parse import LlamaParse
from llama_index.core import SimpleDirectoryReader
from os import getenv
from dotenv import load_dotenv
import asyncio
import nest_asyncio

# Habilitar nested asyncio (necessário em Jupyter ou ambientes interativos)
nest_asyncio.apply()

# Configurar o parser
load_dotenv()
parser_key = getenv('parser_key')
parser = LlamaParse(
    api_key=parser_key,
    result_type="markdown"  # ou "text"
)

# Função assíncrona para carregar os documentos
async def load_documents():
    # Configurar o extrator de arquivos
    file_extractor = {".pdf": parser}
    # Usar SimpleDirectoryReader para carregar o arquivo
    reader = SimpleDirectoryReader(
        input_files=['data/TESTE_CONTO.pdf'],
        file_extractor=file_extractor
    )
    # Carregar dados (assíncrono)
    documents = await reader.aload_data()
    return documents

# Executar no loop de eventos
if __name__ == "__main__":
    # Rodar a função assíncrona
    documents = asyncio.run(load_documents())
    print(documents)
# Out:
# Started parsing the file under job_id 6dae1a05-e595-4fbc-93bc-14180669915b
# [Document(id_='f89502c5-98ab-4be7-8370-6c433aaae492', embedding=None, metadata={'file_path': 'data\\TESTE_CONTO.pdf', 'file_name': 'TESTE_CONTO.pdf', 'file_type': 'application/pdf', 'file_size': 69984, 'creation_date': '2025-01-03', 'last_modified_date': '2025-01-03'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='# A raposa e o tucano\n\nCerta vez uma raposa convidou o tucano para o jantar. A comida era um mingau servido em cima de uma pedra. O pobre tucano teve dificuldade para comer e machucou seu longo bico.\n\nCom raiva, o tucano quis se vingar. Assim, convidou a raposa pra uma refeição em sua casa. Ele disse:\n\n— Amiga raposa, como você me convidou para jantar outro dia, chegou minha vez de retribuir. Venha até minha casa hoje na hora do jantar que servirei uma bela refeição.\n\nA raposa rapidamente se animou e disse que sim.\n\nO tucano então preparou um delicioso mingau e serviu em um comprido jarro. A raposa, faminta, não conseguiu comer do mingau, lambendo apenas um pouco que caíra na mesa.\n\nEnquanto isso o tucano se deliciava com a comida e disse:\n\n— Raposa, a senhora teve o que mereceu, pois fez o mesmo comigo. Fiz isso para te mostrar que não deve querer ser mais esperta do que os outros.', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'), Document(id_='1e3f8f11-434c-48ea-9833-dee1875c8607', embedding=None, metadata={'file_path': 'data\\TESTE_CONTO.pdf', 'file_name': 'TESTE_CONTO.pdf', 'file_type': 'application/pdf', 'file_size': 69984, 'creation_date': '2025-01-03', 'last_modified_date': '2025-01-03'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], excluded_llm_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_date', 'last_accessed_date'], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text_resource=MediaResource(embeddings=None, data=None, text='# A raposa e o tucano\n\nA raposa e o tucano é um conto brasileiro que, usando a figura de animais, nos revela sobre o comportamento humano.\n\nSão tratados sentimentos como a soberba e a raiva, enquanto nos mostra atitudes desagradáveis com o próximo.\n\nA raposa, se achando muito esperta, fez uma “brincadeira” com o tucano, mas não esperava que também passaria pela mesma situação.\n\nEsse é um conto que nos alerta: Não faça com o outro o que não gostaria que fizessem com você.\n\n# 2. Malazarte cozinhando sem fogo\n\nChegando à cidade, Pedro Malazarte foi se divertir em festas e bares e gastou suas economias. Mas antes de ficar de todo pobre, comprou uma panela e um pouco de comida e seguiu seu rumo.\n\nNo meio do caminho, viu uma casa abandonada e parou para descansar. Acendeu um fogo e colocou a comida na panela para aquecer.\n\nPercebendo que chegava uma tropa, Pedro apagou rapidamente o fogo. A comida já estava quente e fumegante. Os homens observaram curiosos e perguntaram:\n\n— Que coisa engraçada, você está cozinhando sem fogo?\n\nE Pedro logo respondeu:', mimetype=None, path=None, url=None), image_resource=None, audio_resource=None, video_resource=None, text_template='{metadata_str}\n\n{content}'), Document(id_='cd5feb37-8d31-4980-b7ec-ec3e8a8684ca', embedding=None, metadata={'file_path': 'data\\TESTE_CONTO.pdf', 'file_name': 'TESTE_CONTO.pdf', 'file_type': 'application/pdf', 'file_size': 69984, 'creation_date': '2025-01-03', 'last_modified_date': '2025-01-03'}, excluded_embed_metadata_keys=['file_name', 'file_type', 'file_size', 'creation_date', 'last_modified_dat ...

# %%
import re
from typing import List, Dict
from llama_index.core import SimpleDirectoryReader
from llama_index.core.schema import TextNode
from llama_parse import LlamaParse
import nest_asyncio

class MarkdownPreprocessor:
    def __init__(self, parser_key: str):
        self.parser_key = parser_key
        self.nodes: List[TextNode] = []
    
    def extract_section_metadata(self, text: str) -> List[Dict]:
        """
        Extrai metadados de seções e divide o texto em parágrafos.
        Retorna uma lista de dicionários com informações das seções e seus parágrafos.
        """
        sections = []
        current_headers = {1: None, 2: None, 3: None, 4: None, 5: None, 6: None}
        
        # Regex para identificar headers markdown (# Header)
        header_pattern = re.compile(r'^(#{1,6})\s+(.+)$', re.MULTILINE)
        
        # Encontrar todas as posições de headers
        headers = list(header_pattern.finditer(text))
        
        if not headers:
            # Se não houver headers, trata o texto inteiro como uma seção
            paragraphs = [p.strip() for p in text.split('\n\n') if p.strip()]
            for idx, paragraph in enumerate(paragraphs, 1):
                sections.append({
                    "text": paragraph,
                    "metadata": {
                        "paragraph_number": idx,
                        "total_paragraphs": len(paragraphs)
                    }
                })
            return sections
        
        for i, match in enumerate(headers):
            level = len(match.group(1))  # Número de #
            title = match.group(2).strip()
            start = match.start()
            
            # Define o fim da seção atual
            end = headers[i + 1].start() if i < len(headers) - 1 else len(text)
            
            # Atualiza headers ativos para este nível
            current_headers[level] = title
            # Limpa subníveis
            for l in range(level + 1, 7):
                current_headers[l] = None
            
            # Cria hierarquia completa
            hierarchy = {
                f"h{l}": current_headers[l]
                for l in range(1, 7)
                if current_headers[l] is not None
            }
            
            # Extrai o texto da seção atual
            section_text = text[start:end].strip()
            
            # Remove o header do início do texto da seção
            section_text = re.sub(r'^#{1,6}\s+.+\n', '', section_text, flags=re.MULTILINE)
            
            # Divide em parágrafos
            paragraphs = [p.strip() for p in section_text.split('\n\n') if p.strip()]
            
            # Cria um node para cada parágrafo
            for p_idx, paragraph in enumerate(paragraphs, 1):
                sections.append({
                    "text": paragraph,
                    "metadata": {
                        "header_level": level,
                        "header_title": title,
                        "paragraph_number": p_idx,
                        "total_paragraphs": len(paragraphs),
                        **hierarchy
                    }
                })
        
        return sections

    async def process_files(self, files: List[str]) -> List[TextNode]:
        """
        Processa arquivos PDF e gera TextNodes com metadados baseados na estrutura markdown,
        dividindo o conteúdo em parágrafos.
        """
        nest_asyncio.apply()
        
        text_nodes = []
        
        parser = LlamaParse(
            api_key=self.parser_key,
            result_type="markdown",
        )

        for file in files:
            try:
                # Configurar extrator
                file_extractor = {".pdf": parser}
                reader = SimpleDirectoryReader(
                    input_files=[file],
                    file_extractor=file_extractor
                )
                
                # Carregar documentos
                documents = await reader.aload_data()
                if not documents:
                    raise ValueError(f"O PDF {file} parece não conter texto processável.")
                
                # Processar cada documento
                for doc in documents:
                    # Extrair seções e parágrafos com metadados
                    sections = self.extract_section_metadata(doc.text)
                    
                    # Criar TextNodes para cada parágrafo
                    for idx, section in enumerate(sections, start=1):
                        metadata = {
                            "filename": file,
                            "chunk_number": idx,
                            **section["metadata"]
                        }
                        
                        text_nodes.append(TextNode(
                            text=section["text"],
                            metadata=metadata
                        ))
                
                print(f"Texto extraído do arquivo {file} com sucesso!")
            
            except Exception as e:
                print(f"Erro ao processar {file}: {str(e)}")
                continue
        
        self.nodes = text_nodes
        return text_nodes

    def get_nodes(self) -> List[TextNode]:
        """Retorna os nodes processados."""
        return self.nodes

# %%
mark = MarkdownPreprocessor(parser_key)
teste = asyncio.run(mark.process_files(['data/TESTE_CONTO.pdf']))
teste
# Out:
# Started parsing the file under job_id e381d3b7-52f0-4b73-8f32-7b42db13191e
# Texto extraído do arquivo data/TESTE_CONTO.pdf com sucesso!
# [TextNode(id_='1217761a-6f8e-4c3c-8f6c-9be655bbf886', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 1, 'header_level': 1, 'header_title': 'A raposa e o tucano', 'paragraph_number': 1, 'total_paragraphs': 7, 'h1': 'A raposa e o tucano'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Certa vez uma raposa convidou o tucano para o jantar. A comida era um mingau servido em cima de uma pedra. O pobre tucano teve dificuldade para comer e machucou seu longo bico.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='f38db1f8-914d-4376-ae86-ced9cb0d3cb0', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 2, 'header_level': 1, 'header_title': 'A raposa e o tucano', 'paragraph_number': 2, 'total_paragraphs': 7, 'h1': 'A raposa e o tucano'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Com raiva, o tucano quis se vingar. Assim, convidou a raposa pra uma refeição em sua casa. Ele disse:', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='2ab7e0e9-0b7b-4905-9686-6a122d14a4e4', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 3, 'header_level': 1, 'header_title': 'A raposa e o tucano', 'paragraph_number': 3, 'total_paragraphs': 7, 'h1': 'A raposa e o tucano'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='— Amiga raposa, como você me convidou para jantar outro dia, chegou minha vez de retribuir. Venha até minha casa hoje na hora do jantar que servirei uma bela refeição.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='b4ca6347-9df4-4b92-9670-9cba003168ae', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 4, 'header_level': 1, 'header_title': 'A raposa e o tucano', 'paragraph_number': 4, 'total_paragraphs': 7, 'h1': 'A raposa e o tucano'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='A raposa rapidamente se animou e disse que sim.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='278b9118-1cd8-4800-ab64-26c6c4cb715a', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 5, 'header_level': 1, 'header_title': 'A raposa e o tucano', 'paragraph_number': 5, 'total_paragraphs': 7, 'h1': 'A raposa e o tucano'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='O tucano então preparou um delicioso mingau e serviu em um comprido jarro. A raposa, faminta, não conseguiu comer do mingau, lambendo apenas um pouco que caíra na mesa.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='e3e55b31-f13a-446d-b6fe-8e4f9efcc9be', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 6, 'header_level': 1, 'header_title': 'A raposa e o tucano', 'paragraph_number': 6, 'total_paragraphs': 7, 'h1': 'A raposa e o tucano'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Enquanto isso o tucano se deliciava com a comida e disse:', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='fb9b69ed-28e4-443d-86c4-0fa2046a5f19', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 7, 'header_level': 1, 'header_title': 'A raposa e o tucano', 'paragraph_number': 7, 'total_paragraphs': 7, 'h1': 'A raposa e o tucano'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='— Raposa, a senhora teve o que mereceu, pois fez o mesmo comigo. Fiz isso para te mostrar que não deve querer ser mais esperta do que os outros.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='95311bbc-c2db-4e56-a3ca-e7d156fba990', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 1, 'header_level': 1, 'header_title': '2. Malazarte cozinhando sem fogo', 'paragraph_number': 1, 'total_paragraphs': 4, 'h1': '2. Malazarte cozinhando sem fogo'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Chegando à cidade, Pedro Malazarte foi se divertir em festas e bares e gastou suas economias. Mas antes de ficar de todo pobre, comprou uma panela e um pouco de comida e seguiu seu rumo.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='c3fc7466-e360-46f5-8d91-90a516d618dd', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 2, 'header_level': 1, 'header_title': '2. Malazarte cozinhando sem fogo', 'paragraph_number': 2, 'total_paragraphs': 4, 'h1': '2. Malazarte cozinhando sem fogo'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='No meio do caminho, viu uma casa abandonada e parou para descansar. Acendeu um fogo e colocou a comida na panela para aquecer.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='d8ddeb04-c91f-41f0-b095-5ad1997b106f', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 3, 'header_level': 1, 'header_title': '2. Malazarte cozinhando sem fogo', 'paragraph_number': 3, 'total_paragraphs': 4, 'h1': '2. Malazarte cozinhando sem fogo'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Percebendo que chegava uma tropa, Pedro apagou rapidamente o fogo. A comida já estava quente e fumegante. Os homens observaram curiosos e perguntaram:', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='ba70b0d3-da1f-4062-902b-4d8e534f1c27', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 4, 'header_level': 1, 'header_title': '2. Malazarte cozinhando sem fogo', 'paragraph_number': 4, 'total_paragraphs': 4, 'h1': '2. Malazarte cozinhando sem fogo'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='— Que coisa engraçada, você está cozinhando sem fogo?', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='8538156b-9ac9-4bdc-be6a-703fa254b07d', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 1, 'header_level': 1, 'header_title': '3. De como Malazarte entrou no céu', 'paragraph_number': 1, 'total_paragraphs': 3, 'h1': '3. De como Malazarte entrou no céu'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Quando Malazarte morreu e chegou ao céu, disse a São Pedro que queria entrar.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='77828344-d562-4e82-a9b7-cd1280a4321f', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 2, 'header_level': 1, 'header_title': '3. De como Malazarte entrou no céu', 'paragraph_number': 2, 'total_paragraphs': 3, 'h1': '3. De como Malazarte entrou no céu'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='O santo respondeu:', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='8909b021-eb1b-4324-b9d2-031a62c7744d', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 3, 'header_level': 1, 'header_title': '3. De como Malazarte entrou no céu', 'paragraph_number': 3, 'total_paragraphs': 3, 'h1': '3. De como Malazarte entrou no céu'}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='— Estás louco! Pois tens coragem de querer entrar no céu, depois que tantas fizeste pelo mundo?!', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='971e6a4c-f45b-44f6-93b1-e6d561ef629d', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 1, 'paragraph_number': 1, 'total_paragraphs': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='— Quero, São Pedro, pois o céu é dos arrependidos, e tudo quanto acontece é por vontade de Deus.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='05120681-d07f-4223-8386-a3c16b124e71', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 2, 'paragraph_number': 2, 'total_paragraphs': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='— Mas teu nome não está no livro dos justos e portanto não entras.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='41ef3679-a051-4096-b90f-83db3d65037e', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 3, 'paragraph_number': 3, 'total_paragraphs': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='— Mas então eu desejava falar com o Padre Eterno.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='472655c4-fce1-46d4-976a-1409d87a2347', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 4, 'paragraph_number': 4, 'total_paragraphs': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='São Pedro se zangou com aquela proposta. E disse:', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='0a6384a1-f0df-451a-a75c-dfe934458d7f', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 5, 'paragraph_number': 5, 'total_paragraphs': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='— Não, para falares a Nosso Senhor, precisavas entrar no céu, e quem entra no céu dele não pode mais sair.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='b46966ea-f33c-4beb-9e2d-b869be0204eb', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 6, 'paragraph_number': 6, 'total_paragraphs': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Malazarte se pôs a lamentar e pediu que o santo ao menos o deixasse espiar o céu, só pela frestinha da porta, para tivesse uma ideia do que fosse o céu e lamentasse o que havia perdido por causa das más artes.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='9dd81927-dde3-41f2-ab8d-d3b65d2c4046', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 7, 'paragraph_number': 7, 'total_paragraphs': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='São Pedro, já amolado, abriu uma fresta da porta e Pedro meteu por ela a cabeça.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='9a38ff57-2027-45bf-a5ab-e9921138f414', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 8, 'paragraph_number': 8, 'total_paragraphs': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Mas de repente gritou:', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='418d23d7-d81e-421f-8b86-a6c78baf68cf', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 9, 'paragraph_number': 9, 'total_paragraphs': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='— Olha, São Pedro, Nosso Senhor, que vem falar comigo. Eu não te dizia!', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='dc0edde5-feda-4394-9289-756c5fd45884', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 10, 'paragraph_number': 10, 'total_paragraphs': 10}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='São Pedro voltou-se com o todo o respeito para dentro do céu, a fim de render as suas homenagens ao Padre Eterno que supunha ali vir.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='cad4da0c-3c04-4a71-8b22-cf868dbd48e3', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 1, 'paragraph_number': 1, 'total_paragraphs': 7}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='E Pedro Malazarte então pulou para dentro do céu.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='acc0a4a4-3b4a-48d6-a562-6c2e42c8b52b', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 2, 'paragraph_number': 2, 'total_paragraphs': 7}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='O santo viu que tinha sido enganado. Quis pôr Malazarte para fora, mas ele contrariou:', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='0162f0f2-43fc-4998-87b4-14a9dcac2f19', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 3, 'paragraph_number': 3, 'total_paragraphs': 7}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='— Agora é tarde! São Pedro, lembre-se que me disse que do céu, uma vez entrando, ninguém pode mais sair. É a eternidade!', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='a4ffd234-8a02-4c85-aec3-3aa4611d65d5', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 4, 'paragraph_number': 4, 'total_paragraphs': 7}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='E São Pedro não teve remédio senão deixar Malazarte lá ficar.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='3e3bf980-8bbb-4ee3-a8a7-e392935f2211', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 5, 'paragraph_number': 5, 'total_paragraphs': 7}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Tirado do livro *Os grandes contos populares do mundo*, de Flávio Moreira da Costa, essa é uma da história que também traz como protagonista a figura icônica de Pedro Malazarte.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='fc8d91a2-1a5f-437a-a494-babec26a8416', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 6, 'paragraph_number': 6, 'total_paragraphs': 7}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='É um conto que nos leva a imaginar a cena e observar a esperteza de Malazarte, que consegue enganar até mesmo os santos.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}'),
#  TextNode(id_='050eae77-e692-4168-956c-2d44e264c538', embedding=None, metadata={'filename': 'data/TESTE_CONTO.pdf', 'chunk_number': 7, 'paragraph_number': 7, 'total_paragraphs': 7}, excluded_embed_metadata_keys=[], excluded_llm_metadata_keys=[], relationships={}, metadata_template='{key}: {value}', metadata_separator='\n', text='Assim, é possível desenvolver empatia e identificação com o personagem, que apesar de trapaceiro apresenta um humor e inteligência admiráveis.', mimetype='text/plain', start_char_idx=None, end_char_idx=None, metadata_seperator='\n', text_template='{metadata_str}\n\n{content}')]
